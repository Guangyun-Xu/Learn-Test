# %% [markdown]
# torchvision是服务于PyTorch深度学习框架的包，主要用来构建计算机视觉模型。

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time
import sys
sys.path.append("..") # 为了导入上层目录的d2lzh_pytorch
import PyCode.PyTorch_Learn.d2lzh_pytorch as d2l

mnist_train = torchvision.datasets.FashionMNIST(root='/media/yumi/Datas/FashionMNIST', train=True, download=True, transform=transforms.ToTensor())
mnist_test = torchvision.datasets.FashionMNIST(root='/media/yumi/Datas/FashionMNIST', train=False, download=True, transform=transforms.ToTensor())
# Out:
# 26427392it [10:56, 96869.27it/s]
# 0it [00:00, ?it/s]
# ...
#  56%|█████▌    | 16384/29515 [00:01<00:00, 29345.54it/s]
# 32768it [00:01, 20557.85it/s]
#
# 0it [00:00, ?it/s]
# ...
#   9%|▉         | 393216/4422102 [00:10<04:04, 16483.19it/s]
# 26427392it [11:10, 96869.27it/s][00:10<03:13, 20734.89it/s]
# ...
# 100%|█████████▉| 4415488/4422102 [01:34<00:00, 97614.65it/s]
#
# 0it [00:00, ?it/s]
#
# 8192it [00:00, 13371.24it/s]
# ...
# Extracting /media/yumi/Datas/FashionMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to /media/yumi/Datas/FashionMNIST/FashionMNIST/raw
# ...
# Extracting /media/yumi/Datas/FashionMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to /media/yumi/Datas/FashionMNIST/FashionMNIST/raw
# ...
# Extracting /media/yumi/Datas/FashionMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to /media/yumi/Datas/FashionMNIST/FashionMNIST/raw
# ...
# Extracting /media/yumi/Datas/FashionMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to /media/yumi/Datas/FashionMNIST/FashionMNIST/raw
# Processing...
# Done!
